# %% [markdown]
# # Taller 0-1 Notebook
# Erick Romero

# %% [markdown]
# ## Graficar Funciones
# $y(x) = x^3 - 7x^2 + 4x + 12$

# %%
# y(x)=x^3-7x^2+4x+12
def eqn(x: int) -> int:
    # ** símbolo de potencia en python, no se usa el `^` como en otros lenguajes
    return x**3 - 7 * x**2 + 4 * x + 12

# %%
# generación de puntos para la gráfica
import numpy as np

## TAREA generar 100 datos del -10 al 10
Xs, step = np.linspace(-10, 10, num=15, retstep=True)

# %%
Ys = []
for x in Xs:
    y = eqn(x)
    # Xs.append(x)
    Ys.append(y)
    print(f"x = {x:.2f} \ty = {y:.2e}")
Ys
# Out:
# x = -5.00 	y = -3.08e+02
# x = 0.00 	y = 1.20e+01
# x = 10.00 	y = 3.52e+02
# [-308, 12, 352]

# %%
from matplotlib import pyplot as plt

# import seaborn as sns ## alternativa chévere

plt.plot(Xs, Ys, marker=".", color="blue", linestyle=":")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.title("Gráfica de función cúbica")
plt.grid()
plt.legend(["$y=x^3-7x^2+4x+12$"])
plt.show()

## TAREA hacer zoom
# Rango de valores para hacer zoom
plt.xlim([-3, 11])
plt.ylim([-30, 410])

plt.plot(Xs, Ys, marker=".", color="blue", linestyle=":")
plt.xlabel("Eje x")
plt.ylabel("Eje y")
plt.title("Gráfica de función cúbica con Zoom")
plt.grid()
plt.legend(["$y=x^3-7x^2+4x+12$"])
plt.show()

# %%
import seaborn as sns

# Datos de ejemplo
Xs = range(-3, 11)
Ys = [x**3 - 7*x**2 + 4*x + 12 for x in Xs]

# Configuración del estilo de Seaborn y creación de la gráfica
sns.set(style="whitegrid")
sns.lineplot(x=Xs, y=Ys, marker="o", color="blue", linestyle=":")

# Personalización
plt.title("Gráfica de función cúbica")
plt.legend(["$y=x^3-7x^2+4x+12$"])
plt.show()
